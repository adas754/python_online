# %%
a=0
if a>2:
    print('yes done')
else:
    print('not satisfied')
# Out:
# not satisfied

# %%
0>2
# Out:
# False

# %%
# find out the number is even or odd
# user will give the input and based on that it will tell number is even or not
n=int(input('Enter the number'))
if n%2==0:
    print('even')
else:
    print('odd')
# Out:
# Enter the number 4
# even

# %%
8%2
# Out:
# 0

# %%
0==0
# Out:
# True

# %%
# try to find the number is positive or -ve
n=int(input('Enter the number'))
if n>0:
    print('+ve')
else:
    print('-ve')
# Out:
# Enter the number -6
# -ve

# %%
# the people will give vote or not
age =int(input("Enter a number"))
if age>=18:
  print("can give vote")
else:
  print("not allow")
# Out:
# Enter a number 18
# can give vote

# %%
# string is palindrom
s=input("Enter the string")
if s==s[::-1]:
    print('palindrom')
else:
    print('not palindrom')
# Out:
# Enter the string no
# not palindrom

# %%
# those are divisible by 5 and 7 
# you will print yes 
# if not 
# you will print no
# 35 , 70,140,105

# %%
140%5
# Out:
# 0

# %%
105%5
# Out:
# 0

# %%
n=int(input('enter no'))
if n%5==0 and n%7==0:
    print('yes')
else:
    print('no')
# Out:
# enter no 35
# yes

# %%
s='mom'
s1=s[::-1]

# %%
s==s1
# Out:
# True

# %%
# write the output if a=9
a=9
if(a>5 and a<=10):
    print('hi')
else:
    print('bye')
# Out:
# hi

# %%
9>5 and 9<=10
# Out:
# True

# %%
n=int(input('Enter the number'))
if n>0:
    print('+ve')
elif n==0:
    print('zero')
else:
    print('-ve')
# Out:
# Enter the number 0
# zero

# %%
n=int(input('Enter the number'))
if n>0:
    print('+ve')
elif n==0:
    print('zero')
else:
    print('-ve')
# Out:
# Enter the number 9
# +ve

# %%
# insta id with that name 'ad123' and
# password ='a123'
# when i want to reopen again if i will mention the same insta id and 
#password then insta will open if not then insta will not open
id=input('enter id')
password=input('password')
if id=='ad123' and password=='a123':
    print('succesfull')
else:
    print('not succesfull')
# Out:
# enter id 33e3
# password ff
# not succesfull

# %%
# if id is correct but password is wrong then again it will ask
# the password , if you entered correct password 
# you are able to login the page
# if again you wrote wrong password then it will tail fail
# if both are wrong then 'not succesfull'

# %%
id=input('enter id')
password=input('password')
if id=='ad123' and password=='a123':
    print('succesfull')
elif id=='ad123' and password!='a123':
    print('plz try again!!!')
    password=input('password')
    if password=='a123':
        print('success')
    else:
        print('wrong')
    
else:
    print('not succesfull')
# Out:
# enter id jjdfjdj
# password kooo
# not succesfull

# %%
# write the prog 
# temp is 30 print moderate 
# less than 30 print cool
# greater than 30 print hot
