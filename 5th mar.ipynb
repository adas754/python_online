# %%
l=[7,8,9,9,0]
l.count(9)
# Out:
# 2

# %%
l.index(9)
# Out:
# 2

# %%
l1=[8,9,0]
l2=[9,8,5]
l1+l2
# Out:
# [8, 9, 0, 9, 8, 5]

# %%
l1*2
# Out:
# [8, 9, 0, 8, 9, 0]

# %%
l2=l1.copy()
l2
# Out:
# [8, 9, 0]

# %%
# tuple
t=()
type(t)
# Out:
# tuple

# %%
t=(9)
type(t)
# Out:
# int

# %%
t=(9,)
type(t)
# Out:
# tuple

# %%
t=90,56,46
type(t)
# Out:
# tuple

# %%
t=(7)
t2=(8,'hk')
t5=8,'y',90
print(type(t))
print(type(t2))
print(type(t5))
# Out:
# <class 'int'>
# <class 'tuple'>
# <class 'tuple'>

# %%
t=(5,8.9,'s',True,[7,89,90],(8,90,90))

# %%
t='python'
# convert str to tuple
t1=tuple(t)
t1
# Out:
# ('p', 'y', 't', 'h', 'o', 'n')

# %%
l=[9,89,80]
t2=tuple(l)
t2
# Out:
# (9, 89, 80)

# %%
t=(9,80,57)
# tup to list
l=list(t)
l
# Out:
# [9, 80, 57]

# %%
t=(1,2,3,4)
t[-1]
# Out:
# 4

# %%
t[0:3]
# Out:
# (1, 2, 3)

# %%
t[0::2]
# Out:
# (1, 3)

# %%
t=(1,2,3,4)
t[::-1]
# Out:
# (4, 3, 2, 1)

# %%
t
# Out:
# (1, 2, 3, 4)

# %%
#t[0]=100
#t

# %%
t=(9,80,0)
t1=(9,0,9)
t1+t
# Out:
# (9, 0, 9, 9, 80, 0)

# %%
t1*7
# Out:
# (9, 0, 9, 9, 0, 9, 9, 0, 9, 9, 0, 9, 9, 0, 9, 9, 0, 9, 9, 0, 9)

# %%
# in
# not in
t2=(99,78,90)
90 in t2
# Out:
# True

# %%
t=(78,78,80,90,8)
for i in t:
    print(i,end=' ')
# Out:
# 78 78 80 90 8

# %%
t
# Out:
# (78, 78, 80, 90, 8)

# %%
print(min(t))
print(max(t))
print(sum(t))
print(sorted(t,reverse=True))
# Out:
# 8
# 90
# 334
# [90, 80, 78, 78, 8]

# %%
78+78+80+90
# Out:
# 326

# %%
t
# Out:
# (78, 78, 80, 90, 8)

# %%
t.count(78)
# Out:
# 2

# %%
t.index(78)
# Out:
# 0

# %%
a,b,*c=89,67,57,90,79,799,90,90,67,90
c # tuple unpacking
# Out:
# [57, 90, 79, 799, 90, 90, 67, 90]

# %%
a
# Out:
# 89

# %%
b
# Out:
# 67

# %%
c
# Out:
# [57, 90, 79, 799, 90, 90, 67, 90]

# %%
a=(7,89,0,90)
b=(7,79,0)
tuple(zip(a,b))
# Out:
# ((7, 7), (89, 79), (0, 0))

# %%
# set
s={}
type(s) # empty set should be dict
# Out:
# dict

# %%
t=(9,)
type(t)
# Out:
# tuple

# %%
# empty set
s=set()
type(s)
# Out:
# set

# %%
s={5,8.9,True,'t'}
type(s)
# Out:
# set

# %%
#s={5,8.9,True,'t',{8,9,0}}

# %%
#s={5,8.9,True,'t',[8,9,0]}

# %%
s={5,8.9,True,'t',(9,0,79)}

# %%
s
# Out:
# {(9, 0, 79), 5, 8.9, True, 't'}

# %%
s={6,9,0,3,0,'python',90,8.8,9078,True,99999999999,778000,'on','an'}
s # set means it will not follow any kind of order
# Out:
# {0, 3, 6, 778000, 8.8, 9, 90, 9078, 99999999999, True, 'an', 'on', 'python'}

# %%
s={6,9,0,3,0}
s
# Out:
# {0, 3, 6, 9}

# %%
s
# Out:
# {0, 3, 6, 778000, 8.8, 9, 90, 9078, 99999999999, True, 'an', 'on', 'python'}

# %%
#s[0]=7

# %%
# set is unordered
# u cant store set inside set
# u can store tuple -> immutable
# cant store list-> mutable

# %%
s=[8,9,90,89,0,0,0,0]
# from that list try to find out unique value
set(s)
# set does not allow any kind of duplicate value
# Out:
# {0, 8, 9, 89, 90}

# %%
s={6,8,9}
s.add(89)
s # add to insert item inside a set
# Out:
# {6, 8, 9, 89}

# %%
s.add((89,9,0))

# %%
s
# Out:
# {(89, 9, 0), 6, 8, 89, 9}

# %%
s={6,8,9}
s.update((90,97,0))

# %%
s
# Out:
# {0, 6, 8, 9, 90, 97}

# %%
s={1,2,3,4,5}
s.discard(5)

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
s.discard(500)

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
s.remove(3)

# %%
s
# Out:
# {1, 2, 4}

# %%
#s.remove(500)

# %%
# remove and discard

# %%
s
# Out:
# {1, 2, 4}

# %%
s.pop()
# Out:
# 1

# %%
s
# Out:
# {2, 4}

# %%
s={8,9,67,90}
s.pop()
# Out:
# 8

# %%
s
# Out:
# {9, 67, 90}

# %%
s={8,9,67,90,3,0,80,-1}
s.pop()
# Out:
# 0

# %%
s
# Out:
# {-1, 3, 8, 9, 67, 80, 90}

# %%
s.clear()

# %%
s # every element from a set
# Out:
# set()

# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1|s2 # union
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1&s2 # intersection
# Out:
# {4, 5}

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2
# Out:
# {4, 5, 6, 7, 8}

# %%
s1-s2
# Out:
# {1, 2, 3}

# %%
s2-s1
# Out:
# {6, 7, 8}

# %%
s={8,9,0,90}
9 in s
# Out:
# True

# %%
9 not in s
# Out:
# False

# %%
s={9,8,90,56}
for i in s:
    print(i)
# Out:
# 8
# 9
# 90
# 56

# %%
# dict
# how to create empty dict
d={}
type(d)
# Out:
# dict

# %%
# name -> 
# roll ->
# city ->

# %%
d={'name':'ad','roll':1,'city':'BLR'}
d
# Out:
# {'name': 'ad', 'roll': 1, 'city': 'BLR'}

# %%
type(d)
# Out:
# dict

# %%
d.keys()
# Out:
# dict_keys(['name', 'roll', 'city'])

# %%
d.values()
# Out:
# dict_values(['ad', 1, 'BLR'])

# %%
d
# Out:
# {'name': 'ad', 'roll': 1, 'city': 'BLR'}

# %%
d.items()
# Out:
# dict_items([('name', 'ad'), ('roll', 1), ('city', 'BLR')])

# %%
d={'name':'ad','age':27,'sub':{'ds':90,'da':78}}

# %%
d['name']
# Out:
# 'ad'

# %%
d['age']
# Out:
# 27

# %%
# 78
d['sub']['da']
# Out:
# 78

# %%
d
# Out:
# {'name': 'ad', 'age': 27, 'sub': {'ds': 90, 'da': 78}}

# %%
d['name']='ak'

# %%
d
# Out:
# {'name': 'ak', 'age': 27, 'sub': {'ds': 90, 'da': 78}}

# %%
# 78 to 95
d['sub']['da']=95

# %%
d
# Out:
# {'name': 'ak', 'age': 27, 'sub': {'ds': 90, 'da': 95}}

# %%
d.pop('age')
# Out:
# 27

# %%
d
# Out:
# {'name': 'ak', 'sub': {'ds': 90, 'da': 95}}

# %%
d
# Out:
# {'name': 'ak', 'sub': {'ds': 90, 'da': 95}}

# %%
d={'name':'ad','ds':90}

# %%
for i in d:
    print(i,d[i])
# Out:
# name ad
# ds 90

# %%
for i,j in d.items():
    print(i,j)
# Out:
# name ad
# ds 90

# %%
# function
# write the prog to add two number
# user input
a=int(input('enter a no'))
b=int(input('enter a no'))
print(a+b)
# Out:
# enter a no 7
# enter a no 8
# 15
