# %%
# cell
a=2
a
# Out:
# 2

# %% [markdown]
# ## Python basic

# %%
'python' 'you can write only the code'
# Out:
# 'pythonyou can write only the code'

# %% [markdown]
# ## python first class

# %%
a=15 # stored 15
a
# Out:
# 15

# %%
a
# Out:
# 15

# %% [markdown]
# # write python program to add two number
# # a=2
# # a

# %% [raw]
# # write python raw we can u for the headline purpose only

# %%
# esc dd-> delete
# esc b -> adding new cell on below
# esc a -> add new cell on above

# %%
'python'
# Out:
# 'python'

# %%
2+3
# Out:
# 5

# %%
'i want to learn python'
# Out:
# 'i want to learn python'

# %%
2
# Out:
# 2

# %%
'''python'''
# Out:
# 'python'

# %%
# datatype of python
a=1
# how to check the datatype
type(a)
# Out:
# int

# %%
a=67
type(a)
# Out:
# int

# %%
a='67'
type(a)
# Out:
# str

# %%
a=67.0
type(a)
# Out:
# float

# %%
a=98.8
type(a)
# Out:
# float

# %%
# we will mention the . then it should be float
# '',"",''' ''' -> string

# %%
a='89.0'
type(a)
# Out:
# str

# %%
# str
# float
# int
# bool
# complex
a=8+9j
type(a)
# Out:
# complex

# %%
a=False
type(a)
# Out:
# bool

# %%
a=True
# what is data type of a it will be bool(boolion)
type(a)
# Out:
# bool

# %%
a=5+7j
type(a)
# Out:
# complex

# %%
# a+ib- > complex
#a= real
#b- real

# %%
a='True'
b='89.00'
c=67.00
d= False
e=9

# %%
# identifier
a=15

# %%
# a-> identifier
# it should start with alphabet, alphanumerical is also fine
# it should not with number
# we cant use any special character except underscore
# reserve notation we will use that particular notation for our specific work that
# we will call keyword, we cant use the keyword as identifier
_=15
_
a1=15
a1
#1a=15
# Out:
# 15

# %%
_
# Out:
# 15

# %%
import keyword
len(keyword.kwlist)
# Out:
# 35

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
#False=9 #keyword we cant use as identifier

# %%
a_1=9
a_1
# Out:
# 9

# %%
_a=7
