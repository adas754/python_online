# %% [markdown]
# ##### Basic python

# %%
# datatype
# int
a=9
type(a)
# Out:
# int

# %%
type(87)
# Out:
# int

# %%
type(5.000)
# Out:
# float

# %%
type('python')
# Out:
# str

# %%
type('2.9')
# Out:
# str

# %%
type("python")
# Out:
# str

# %%
type('''python''')
# Out:
# str

# %%
type('''''''python''''''')
# Out:
# str

# %%
# int
# str
# float
# bool
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(9+8j)
# Out:
# complex

# %%
type('6.9')
# Out:
# str

# %%
print(type(0.0)) # float
print(type('9.89')) # str
print(type('true')) # str
# Out:
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %%
# identifier
# how to define identifier
# alphabet no problem
#alphabet+number no problem
# special character !,$,%,^,&,*,- we cant use except
# _
#number as starting we cant take as identifier
a1=23
a=9 
num=9
_=9

# %%
___=9

# %%
# rules
# if we will start with alphabet np
# if we will start with number p
# alpha numerical ( starts with alphabet or _)
# spc char except _ (error)
# we cant use keyword as identifier

_8=9
number_2=89

# %%
number_2
# Out:
# 89

# %%
import keyword
len(keyword.kwlist)
# Out:
# 35

# %%
#elif=56

# %%
# operator

# %%
# datatypes
# int
# float
# str
# bool
# complex
# identifier
# we have to starts with alphabet or _
# keyword we cant use as identifier

# %%
# arithmatic operator
4+6
5-0
9*7
# +,-,*
7/3
# Out:
# 2.3333333333333335

# %%
7//3
# Out:
# 2

# %%
7//2
# Out:
# 3

# %%
7%4
# Out:
# 3

# %%
8%2
# Out:
# 0

# %%
8//5
# Out:
# 1

# %%
76%2
# Out:
# 0

# %%
45//8
# Out:
# 5

# %%
56%3
# Out:
# 2

# %%
# +,-,*,/,//,%,**
# 3:48
# relational operator
# >,<,<=,>=,!=,==

6!=9
# Out:
# True

# %%
2**3
# Out:
# 8

# %%
4**5
# Out:
# 1024

# %%
4*3
# Out:
# 12

# %%
# logical operator
# and
# or
# not
1 and 1
# Out:
# 1

# %%
1 or 1
# Out:
# 1

# %%
not 1
# Out:
# False

# %%
# arithmatic (+,-,*,/,//,%,**)
# relational ( ==,!=,>,<,>=,<=)
# logical operator(and or not)
# assignment (+=,-=,*=,/=,//=,%=,**=)
# membership op( in,not in)

a=8
#a=a+2
a%=2
a
# Out:
# 0

# %%
a=6
a**=3
a
# Out:
# 216

# %%
a=9
a+=9
a
# Out:
# 18

# %%
a=9
a=a+2 # a+=2
a
# Out:
# 11

# %%
'P' in 'python'
# Out:
# False

# %%
'xx' not in 'xerox'
# Out:
# True

# %%
9
# Out:
# 9

# %%
'njjjfjdxszdjdsjfsjl'
# Out:
# 'njjjfjdxszdjdsjfsjl'

# %%
print('python')
# Out:
# python

# %%
print('hi student')
# Out:
# hi student

# %%
print(True)
# Out:
# True

# %%
print(9,9.8,'hi',True,8+9j,sep=' ')
# Out:
# 9 9.8 hi True (8+9j)

# %%
print('hi',end=' ')
print('life')
# Out:
# hi life

# %%
# datatypes
type('9.000')
# Out:
# str

# %%
type(9.0)
# Out:
# float

# %%
type(False)
# Out:
# bool

# %%
_=90
#for=90

# %%
# operator
7/7
# Out:
# 1.0

# %%
# +,-,**,/,//,%,**
# relational op (==,!=,>=,<=,>,<)
# logical (or and not)
1 and 0
# assignment op
# ( +=,-=,*=,
# Out:
# 0

# %%
# assignment
a=9
a+=9
a
# Out:
# 18
