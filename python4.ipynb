# %%
s='welcome to python'
s[7:0:-1]
# Out:
# ' emocle'

# %%
s[5:0:-1]
# Out:
# 'mocle'

# %%
s
# nohtyp
# Out:
# 'welcome to python'

# %%
s[:10:-1]
# Out:
# 'nohtyp'

# %%
s[-1:-7:-1]
# Out:
# 'nohtyp'

# %%
s[-1:-7:1]
# Out:
# ''

# %%
s[10:-1]
# Out:
# ' pytho'

# %%
s
# Out:
# 'welcome to python'

# %%
print('hi'+' '+'python')
# Out:
# hi python

# %%
print('hi'*5)
# Out:
# hihihihihi

# %%
a=float(input())
b=int(input())
print(a+b)
# Out:
#  9
#  9
# 18.0

# %%
a='8'
type(a)
# Out:
# str

# %%
'p' not in 'python'
# Out:
# False

# %%
s
# Out:
# 'welcome to python'

# %%
s.capitalize() # it will convert first letter to capital letter
# Out:
# 'Welcome to python'

# %%
s.title() #starting of word shold be capital
# Out:
# 'Welcome To Python'

# %%
s.upper() # i want to convert every letter
# Out:
# 'WELCOME TO PYTHON'

# %%
s.lower()
# Out:
# 'welcome to python'

# %%
s='PyThoN'
s.swapcase()
# Out:
# 'pYtHOn'

# %%
s='my name is python'
s.count('p')
# Out:
# 1

# %%
s
#s.find('n')
# Out:
# 'my name is python'

# %%
s.find('m')
# Out:
# 0

# %%
'my name is python'
s.find('m')
# Out:
# 0

# %%
s
# Out:
# 'my name is python'

# %%
s.find('a') #it is giving the particular index
# Out:
# 4

# %%
s.index('a')
# Out:
# 4

# %%
# find and index both are giving the index value
s
# Out:
# 'my name is python'

# %%
s.find('z')
# Out:
# -1

# %%
#s.index('z')

# %%
# if anything is not there find will give -1
# if anything is not there index will give error
# both are giving index position

# %%
s
# Out:
# 'my name is python'

# %%
s.startswith('n')
# Out:
# False

# %%
s.endswith('z')
# Out:
# False

# %%
s.startswith('M')
# Out:
# False

# %%
name='python'
work='language'
s='my name is {0}, and i am a {1}'
s.format(work,name )# string format
# Out:
# 'my name is language, and i am a python'

# %%
s='python15.8'
s.isalnum() # when there is only combination of alphabet and 
#numerical it will give true,
# otherwise it will give false if there is spec char
# Out:
# False

# %%
# isalpha
s='ajk667'
s.isalpha() # should  be all alphabet
# Out:
# False

# %%
s='989'
s.isdigit()
# Out:
# True

# %%
s
# Out:
# '989'

# %%
s
# Out:
# 'welcome to python'

# %%
s.split()
# Out:
# ['welcome', 'to', 'python']

# %%
s='welcome # to # python'

# %%
s.split('#')
# Out:
# ['welcome ', ' to ', ' python']

# %%
word=['welcome', 'to', 'python']

# %%
' '.join(word)
# Out:
# 'welcome to python'

# %%
# string -> list -> split
# list -> string -> join

# %%
s
# Out:
# ''

# %%
s='welcome  to python'

# %%
s.replace('python','pythons')
# Out:
# 'welcome  to pythons'

# %%
# strip
#len
# sort
# sorted
s='my name is python'
s.strip() # remove the extra space
# Out:
# 'my name is python'

# %%
len(s)
# Out:
# 17

# %%
s='hello world'
sorted(s,reverse=True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %%
s='hello world'
sorted(s) # it will convert ascending order
# Out:
# [' ', 'd', 'e', 'h', 'l', 'l', 'l', 'o', 'o', 'r', 'w']

# %%
s
# Out:
# 'hello world'

# %%
l=[8,9,0]
l.sort()

# %%
l
# Out:
# [0, 8, 9]

# %%
s
# Out:
# 'hello world'

# %%
min(s)
# Out:
# ' '

# %%
max(s)
# Out:
# 'w'

# %%
s='hello worldz'
max(s)
# Out:
# 'z'

# %%
# f string
name='python'
subject='lang'
s=f"my name is {name}, i am a {subject}"
s
# Out:
# 'my name is python, i am a lang'

# %%
s=f"my name is {subject}, i am a {name}"

# %%
s
# Out:
# 'my name is lang, i am a python'
