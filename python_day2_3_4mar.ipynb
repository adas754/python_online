# %%
# datatype
# int
# float
# bool
# str
# complex
# identifier
# strts with alohabet or _
# operator
# arithmatic op (+,- ,*,/,//,%,**)
# relational op(==,!=,<=,>=,>,<)
# logical op(and,or, not)
# assignment op(+=,-=,..................)
# membership( in, not in)
# sep
# end
# Out:
# 1

# %%
# i want to take input
# user input
# dont use user input
# add two number
a=9
b=10
a+b
# Out:
# 19

# %%
a=input('enter the no')
type(a)
# Out:
# enter the no 9
# str

# %%
a=input('enter the no')
b=input('enter the no')
a+b
# Out:
# enter the no 3
# enter the no 4
# '34'

# %%
'hi'+' python'
# Out:
# 'hi python'

# %%
a=int(input('enter the no'))
b=int(input('enter the no'))
c=a+b
print('The answer is',c)
# Out:
# enter the no 7
# enter the no 0
# The answer is 7

# %%
# take the user input
# do multiplication
# multiply two number
a=int(input('enter the no'))
b=int(input('enter the no'))
c=a*b
print('The answer is',c)
# Out:
# enter the no 7
# enter the no 9
# The answer is 63

# %%
a=float(input('enter the no'))
b=float(input('enter the no'))
c=a*b
print('The answer is',c)
# Out:
# enter the no 8
# enter the no 9
# The answer is 72.0

# %%
a=eval(input('enter the no'))
b=eval(input('enter the no'))
c=a*b
print('The answer is',c)
# Out:
# enter the no 4
# enter the no 7
# The answer is 28

# %%
# u have two swap the number
a=9
b=6
# after swapping
a=6
b=9

# %%
a=int(input('enter 1st no'))
b=int(input('enter 2nd no'))
a=a+b
b=a-b
a=a-b
print('after swapping',a)
print('after swapping',b)
# Out:
# enter 1st no 9
# enter 2nd no 6
# after swapping 6
# after swapping 9

# %% [markdown]
# a=9
# b=6
# a=a+b
# =9+6
# =15
# b=a-b
# =15-6
# =9
# a=a-b
# =15-9
# =6
# # dryrun

# %%
# string
a='python'
# indexing
a[5]
# Out:
# 'n'

# %%
# p->0
# y->1
# t->2
#h ->3
# o-4
# n =5

# %%
a='welcome to python'
a[-10]
a[-5]
# w->0
# e->1
# l->2
# c-3
# o- 4
# m->5
# e-6
# ''->7
# t->8
# o-9
#''->10
# p->11
# y- 12
# t- 13
# h-14
# 0- 15
# n- 16
# Out:
# 'y'

# %%
#slicing
a='welcome to python'
a[0:8]
# to
# py
#on
# ython
a[12:]
#a[15:1000000000000000000]
# starting
# end
# step
# Out:
# 'ython'

# %%
a='welcome to python'
a[0:7:1]
# Out:
# 'welcome'

# %%
a[0:7:2]
# Out:
# 'wloe'

# %%
a='python'
# po
#ph
# pn
a[0:6:5]
#a[0:6:3]
#a[0:6:4]
# Out:
# 'pn'

# %%
a='welcome to python'
# yt
a[-4:-6]
#wy
a[0:13:12]
a[0:16:12]
# slicing using -ve indexing
# no
#eomc
a[-16:-13]
#a[-1:-3:-1]
a='welcome to python'
#n->-1
#o->-2
#h->-3
# t->-4
# y ->-5
#p->-6
#''->-7
#o->-8
#t->=-9
#''->-10
# e->11
# m->12
# o->-13
#c->-14
# l->-15
#e->-16
# w->-17
a='welcome to python'
# emoc
#a[-11:-15:-1]

# %%
a='welcome to python'
# yt
a[-4:-6:-1]
# Out:
# 'ty'

# %%
a[-5:-3]
# Out:
# 'yt'

# %%
a
# Out:
# 'welcome to python'

# %%
a[::]
# Out:
# 'welcome to python'

# %%
a[::-1]
# Out:
# 'nohtyp ot emoclew'

# %%
# mom
# ada
# madam
a
# Out:
# 'welcome to python'

# %%
# inbuild method in str
# i want to check length of the string
len(a)
# Out:
# 17

# %%
a
# Out:
# 'welcome to python'

# %%
min(a)
# Out:
# ' '

# %%
max(a)
# Out:
# 'y'

# %%
'mumbai'>'pune'
# Out:
# False

# %%
'delhi'!='delhi'
# Out:
# False

# %%
sorted(a,reverse=True)
# Out:
# ['y',
#  'w',
#  't',
#  't',
#  'p',
#  'o',
#  'o',
#  'o',
#  'n',
#  'm',
#  'l',
#  'h',
#  'e',
#  'e',
#  'c',
#  ' ',
#  ' ']

# %%
#user input
# done some prog
# indexing
# slicing
# len
# min
# max
# sorted
a='python'
a[::-1]
# Out:
# 'nohtyp'

# %%
# string inbuild function
# conditional statement
# loop
# list ,tuple,set, dictionary

# %%
s='welcome to python'
# emocl
s[-11:-16:-1]
# Out:
# 'emocl'

# %%
s=124
# that number to str
s1=str(s)
type(s1)
# Out:
# str

# %%
s='welcome to python'
len(s)
# Out:
# 17

# %%
#arithmatic op
'delhi'+' kolkata'
# Out:
# 'delhi kolkata'

# %%
'kolkata '*3
# Out:
# 'kolkata kolkata kolkata '

# %%
'Python'>'python'
# Out:
# False

# %%
'hi' and 'python'
# Out:
# 'python'

# %%
'boxing' and 'mma'
# Out:
# 'mma'

# %%
'boxing' or 'mma'
# Out:
# 'boxing'

# %%
'da' or 'ds'
# Out:
# 'da'

# %%
'da' and 'ds'
# Out:
# 'ds'

# %%
'sandeep' or 'mukesh'
# Out:
# 'sandeep'

# %%
'' and 'python'
# Out:
# 'python'

# %%
'p'  not in 'Python'
# Out:
# True

# %%
s
# Out:
# 'welcome to python'

# %%
min(s)
# Out:
# ' '

# %%
max(s)
# Out:
# 'y'

# %%
sorted(s,reverse=True)
# Out:
# ['y',
#  'w',
#  't',
#  't',
#  'p',
#  'o',
#  'o',
#  'o',
#  'n',
#  'm',
#  'l',
#  'h',
#  'e',
#  'e',
#  'c',
#  ' ',
#  ' ']

# %%
s='hi python'
s.capitalize()
# Out:
# 'Hi python'

# %%
s='welcome to python'
s.capitalize()
# Out:
# 'Welcome to python'

# %%
s.title()
# Out:
# 'Welcome To Python'

# %%
s.upper()
# Out:
# 'WELCOME TO PYTHON'

# %%
s='WELCOME TO PYTHON'
s.lower()
# Out:
# 'welcome to python'

# %%
s='WeLcome'
s.swapcase()
# Out:
# 'wElCOME'

# %%
# upper -> entire sent will be capital
# lower->entire sent will be lower
# capitalize -> only first letter from sent
# title -> in sent starting word
# swapcase-> capital will become
# small and ........

# %%
s='welcome to python'
s.count('n')
# Out:
# 1

# %%
s='welcome to python'
s.find('')
# Out:
# 0

# %%
s='welcome to python'
s.index('w')
# Out:
# 0

# %%
# index and find'
# if char is not there index will
# give the error
# find -1
# it is trying to find index

# %%
s
# Out:
# 'welcome to python'

# %%
s.startswith('W')
# Out:
# False

# %%
s
# Out:
# 'welcome to python'

# %%
s.endswith('pn')
# Out:
# False

# %%
#isalnum/isalpha/isdigit/ isidentifier

# %%
a='788@'
a.isalnum()
# alphabet 
# numerical
# alpha numerical
# spc char
# Out:
# False

# %%
a=' op '
a.isalpha()
# only alphabet
# Out:
# False

# %%
a='101000000'
a.isdigit()
# it will take only int
# Out:
# True

# %%
a='#7'
a.isidentifier()
# Out:
# False

# %%
#isalnum- > both alphabet and int
# isalpha -> only alphabet
# isdigit -> it will take only int
# isidentifier - > alpha numerical(int)

# %%
a='ad89.0'
a.isalnum()
# Out:
# False

# %%
a9=5

# %%
'my name is python'.split()
# Out:
# ['my', 'name', 'is', 'python']

# %%
' '.join(['my', 'name', 'is', 'python'])
# Out:
# 'my name is python'

# %%
# list to str- > join
# str to list - > split

# %%
'my name is python'.replace('p','c')
# Out:
# 'my name is cython'

# %%
'my name is python'.replace('python','c')
# Out:
# 'my name is c'

# %%
'a          '.strip()
# Out:
# 'a'

# %%
'  a   '.lstrip()
# Out:
# 'a   '

# %%
'  a   '.rstrip()
# Out:
# '  a'

# %%
'  a   '.strip()
# Out:
# 'a'

# %%
# format
a='python'
b='prog'
s='my name is {1} , i am {0}'
s.format(b,a)
# 0 py
# b- pr
# Out:
# 'my name is python , i am prog'

# %%
a='boxing'
b='sports'
f'my name is {a} it is {b}'
# Out:
# 'my name is boxing it is sports'

# %%
# conditional statement
a=9
if a>59:
    print('yes')
else:
    print('no')
# Out:
# no

# %%
9>5
# Out:
# True

# %%
# to check student will go for school or not
age=int(input("Enter your age"))
if age>=18 and age<=23:
    print('college')
elif age>=3 and age<=17:
    print('school')
else:
    print('job')
# Out:
# Enter your age 23
# college

# %%
# check the number is even or odd
n=int(input()) #9
if n%2==0: #9%2 1==0
    print('even')
else:
    print('odd')
# Out:
#  9
# odd

# %%
90%2
# Out:
# 0

# %%
9%2
# Out:
# 1

# %%
1==0
# Out:
# False

# %%
0==0
# Out:
# True

# %%
user_email=input('enter your email id')
user_password=input('enter your password')
if user_email=='ad@gmail.com' and user_password=='m123@':
    print('login done')
elif user_email=='ad@gmail.com' and user_password!='m123@':
    print('password is wrong')
    user_password=input('enter password')
    if user_password=='m123@':
        print('correct one')
    else:
        print('wrong')
else:
    print('fail')
# Out:
# enter your email id ad@gmail.com
# enter your password 45
# password is wrong
# enter password 88
# wrong

# %%
# check the string is palindrom or not
s=input('Enter the string')
if s==s[::-1]:
    print('palindrom')
else:
    print('not palindrom')
# Out:
# Enter the string eye
# palindrom

# %%
s='python'
s[::-1]
# Out:
# 'nohtyp'

# %%
# check the number is positve or -ve
# 9 +ve
# -3 -ve
n=int(input('Enter the no:'))
if n<0:
    print('-ve')
else:
    print('+ve')
# Out:
# Enter the no: 0
# +ve

# %%
n=int(input('Enter the no:'))
if n>0:
    print('+ve')
elif n==0:
    print('zero')
elif n<0:
    print('-ve')
else:
    print('nothing!!!!!')
# Out:
# Enter the no: 7
# +ve

# %%
# age 3-> 17 school
# age 18 to 28 college
# job
age=int(input('Enter age'))
if age>=3 and age<=17:
    print('school')
elif age>=18 and age<=28:
    print('college')
elif age>=0 and age<=2:
    print('play and sleep')
else:
    print('job')
# Out:
# Enter age 1
# play and sleep

# %%
# if temp is in between 30 to 50 hot
# ---------------------- 10 to 29 modarate
# --------------------- 1 to 9 cool
# less than one than write don't go anywhere
temp=eval(input('enter the temp'))
if temp>=1 and temp<=9:
    print('cool')
elif temp>=10 and temp<=29:
    print('modarate')
elif temp>=30 and temp<=50:
    print('hot')
else:
    print("do't go anywhere")
# Out:
# enter the temp 52
# do't go anywhere

# %%
# u are trying to login in insta
# if ur user_email=='ad123@gmail.com'
# if password=='m123@'
# login done
# user_email !='ad123@gmail.com' and password!='m123@'
# unable to login
user_email=input('Enter email_id')
password=input('enter password')
if user_email=='ad123@gmail.com' and password=='m123@':
    print('login done!!!!!!!!!!')
elif user_email=='ad123@gmail.com' and password!='m123@':
    print('wrong password')
    password=input('enter password')
    if password=='m123@':
        print('correct password,login done')
    else:
        print("How you have forgotten password")
else:
    print('unable to login')
# Out:
# Enter email_id ad123@gmail.com
# enter password 78
# wrong password
# enter password m123@
# correct password,login done

# %%
# if coding score 0 to 29
# plz practice the code
# 30 to 69
# solve more leetcode question
# 60 to 79
#solve less problem focus on ml
# 80 to 100
# go and play
coding_score=int(input('enter the coding score'))
if coding_score>=0 and coding_score<=29:
    print('plz practice more')
elif coding_score>=30 and coding_score<=59:
    print('solve more leetcode question')
elif coding_score>=60 and coding_score<=79:
    print('solve less problem focus on ml')
elif coding_score>=80 and coding_score<=100:
    print(' go and play')
else:
    print('watch netflix !!')
# Out:
# enter the coding score 101
# watch netflix !!

# %%
# if the number divisible by 5 and 7 
# print divisible by 5 and 7
# if not divisible 
# print 'learn maths'
# divisible by 5
# print('ok')
# divisible by 7
# print('not ok')
n=int(input('enter the number'))
if n%5==0 and n%7==0:
    print('divisible by 5 and 7')
elif n%5==0 and n%7!=0:
    print('ok')
elif n%5!=0 and n%7==0:
    print('not ok')
else:
    print('learn maths')
# Out:
# enter the number 788
# learn maths

# %%
# 4:07
# for
# while
# 1 to 1000
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %%
# 1 to 10
# while loop
i=1
while i<5:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4

# %%
# 5 4 3 2 1
