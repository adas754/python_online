# %%
# how to create a empty tuple
t=()
type(t)
# Out:
# tuple

# %%
t=(2,)

# %%
type(t)
# Out:
# tuple

# %%
t=79,89,90,'python'
type(t)
# Out:
# tuple

# %%
t=8,
type(t)
# Out:
# tuple

# %%
t=8
type(t)
# Out:
# int

# %%
t1=(1,2,56,9)# homo
t2=(1,2.5,True,[8,9])# hetro
# nested
t3=(1,2,(4,5))
type(t3)
# Out:
# tuple

# %%
# how to convert str to tup
t2='hello'
t3=tuple(t2)
t3
# Out:
# ('h', 'e', 'l', 'l', 'o')

# %%
# how to access items
t=(1,2,3,4)
t[0]
# Out:
# 1

# %%
# 3 -ve indexing
t[-2]
# Out:
# 3

# %%
t
# Out:
# (1, 2, 3, 4)

# %%
# 1,2,3
t[0:3]
# Out:
# (1, 2, 3)

# %%
t # 1,3
# Out:
# (1, 2, 3, 4)

# %%
t[0::2]
# Out:
# (1, 3)

# %%
t[0:3:2]
# Out:
# (1, 3)

# %%
# editing or deleting time

# %%
t
# Out:
# (1, 2, 3, 4)

# %%
#t[0]=100

# %%
t
# Out:
# (1, 2, 3, 4)

# %%
list(t)
# Out:
# [1, 2, 3, 4]

# %%
# arithmatic op
# +,*

# %%
t1=(1,2,3,4)
t2=(5,6,7,8)
t1+t2
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
t1*2
# Out:
# (1, 2, 3, 4, 1, 2, 3, 4)

# %%
t1=(1,2,3,4)  # membership op
3 not in t1
# Out:
# False

# %%
t=(1,2,3,4)
# use for loop and try to extract 
# 1 2 3 4
for i in t:
    print(i,end=' ')
# Out:
# 1 2 3 4

# %%
t
# Out:
# (1, 2, 3, 4)

# %%
print(len(t))
print(max(t))
print(min(t))
print(sum(t))
print(sorted(t,reverse=True))
# Out:
# 4
# 4
# 1
# 10
# [4, 3, 2, 1]

# %%
t1=(1, 2, 3,3 ,4,4)
# count
t1.count(4)
# Out:
# 2

# %%
# what is the index of 2
t1.index(2)
# Out:
# 1

# %%
# tuple unpacking
a,b,*c=(1,2,3,8,9,6,6,5,4,6)

# %%
c
# Out:
# [3, 8, 9, 6, 6, 5, 4, 6]

# %%
a,b,*other=[1,2,3,8,9,6,6,5,4,6]
other
# Out:
# [3, 8, 9, 6, 6, 5, 4, 6]

# %%
# zip
a=(1,2,3,4,9)
b=(5,6,7,8,2)
list(zip(a,b))
# Out:
# [(1, 5), (2, 6), (3, 7), (4, 8), (9, 2)]

# %%
#set

# %%
l=[]
t=()
s={} # empty set should be always dictionary
type(s)
# Out:
# dict

# %%
# how to create empty set
s=set()
type(s)
# Out:
# set

# %%
# 1d set
s1={2,4,7}
s1
# Out:
# {2, 4, 7}

# %%
# 2d set
#s2={2,3,4,{4,5}}
#s2 # nested set is not possible

# %%
s3={3,4.5,'hi',(4,5)}
s3
# Out:
# {(4, 5), 3, 4.5, 'hi'}

# %%
#s3={3,4.5,'hi',[4,5]}
#s3 # only immutable allowed

# %%
# access items
s={1,2,3,9,78,56,45,'python',7788899,4556,9.0,45.9}
s
#s[0] # set is unordered
# Out:
# {1, 2, 3, 45, 45.9, 4556, 56, 7788899, 78, 9, 'python'}

# %%
# how to add element inside a set
s={1,3,5,7}
s.add((9,9,7))
s
# Out:
# {(9, 9, 7), 1, 3, 5, 7}

# %%
s={1,3,5,7}
s.update((8,9,6))
s
# Out:
# {1, 3, 5, 6, 7, 8, 9}

# %%
# when i want to add multiple value use the update
# single value use the add

# %%
# how to delete the item
s={1,2,3,4,5}
s.discard(50)

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s={1,2,3,4,5}
#s.remove(50)

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s={2,3,5,8,9,1,0}
s.pop()
# Out:
# 0

# %%
s
# Out:
# {1, 2, 3, 5, 8, 9}

# %%
s={8,9,5,60}
s.pop()
# Out:
# 8

# %%
s
# Out:
# {5, 9, 60}

# %%
l=[3,4,5]
l.pop()
# Out:
# 5

# %%
s={3,4,5}
s.pop()
# Out:
# 3

# %%
s={2,3,5,8,9,1,0,0.5,0.02,90,0.0001,56}
s.pop()
# Out:
# 0

# %%
s
# Out:
# {0.0001, 0.02, 0.5, 1, 2, 3, 5, 8, 9, 56, 90}

# %%
s
# Out:
# {0.0001, 0.02, 0.5, 1, 2, 3, 5, 8, 9, 56, 90}

# %%
s
# Out:
# {0.0001, 0.02, 0.5, 1, 2, 3, 5, 8, 9, 56, 90}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
# union , intersection,difference
s1={1,2,3,4,5}
s2={4,5,6,7,8}
s1|s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}
s1&s2
# Out:
# {4, 5}

# %%
s1.intersection(s2)
# Out:
# {4, 5}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}
s1-s2 # s1, not allow the common element
# Out:
# {1, 2, 3}

# %%
s2-s1
# Out:
# {6, 7, 8}

# %%
s1={1,2,3,4,5}
5 not in s1
# Out:
# False

# %%
# how to extract the value using for loop
for i in s1:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
s={5,5,8,9,0}
s # not allow the duplicate
# how to remove duplicate item
# Out:
# {0, 5, 8, 9}

# %%
l=[9,6,7,4,3,2,2,2]
set(l)
# Out:
# {2, 3, 4, 6, 7, 9}

# %%
# dictionary

# %%
# we can store key and value
d={'name':'ganesh','age':20,'sub':'ds'}

# %%
d
# Out:
# {'name': 'ganesh', 'age': 20, 'sub': 'ds'}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'sub'])

# %%
d.values()
# Out:
# dict_values(['ganesh', 20, 'ds'])

# %%
d={'name':'ganesh','age':20,'sub':{'ds':89,'da':80,'bd':70}}

# %%
d
# Out:
# {'name': 'ganesh', 'age': 20, 'sub': {'ds': 89, 'da': 80, 'bd': 70}}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'sub'])

# %%
d.values()
# Out:
# dict_values(['ganesh', 20, {'ds': 89, 'da': 80, 'bd': 70}])

# %%
d
# Out:
# {'name': 'ganesh', 'age': 20, 'sub': {'ds': 89, 'da': 80, 'bd': 70}}

# %%
# extract the value
d['name']
# Out:
# 'ganesh'

# %%
d['age']
# Out:
# 20

# %%
d
# Out:
# {'name': 'ganesh', 'age': 20, 'sub': {'ds': 89, 'da': 80, 'bd': 70}}

# %%
# 80
d['sub']
# Out:
# {'ds': 89, 'da': 80, 'bd': 70}

# %%
d['sub']['da']
# Out:
# 80

# %%
d
# Out:
# {'name': 'ganesh', 'age': 20, 'sub': {'ds': 89, 'da': 80, 'bd': 70}}

# %%
d['sub']['bd']
# Out:
# 70

# %%
# want to change the value

# %%
d['name']='ad'

# %%
d['sub']['bd']
# Out:
# 70

# %%
d['name']='ad' # if you want you can change the value

# %%
d
# Out:
# {'name': 'ad', 'age': 20, 'sub': {'ds': 89, 'da': 80, 'bd': 70}}

# %%
# 20 to 26
d['age']=26

# %%
d
# Out:
# {'name': 'ad', 'age': 26, 'sub': {'ds': 89, 'da': 80, 'bd': 70}}

# %%
# 89 to 78
d['sub']['ds']=78

# %%
d
# Out:
# {'name': 'ad', 'age': 26, 'sub': {'ds': 78, 'da': 80, 'bd': 70}}

# %%
d
# Out:
# {'name': 'ad', 'age': 26, 'sub': {'ds': 78, 'da': 80, 'bd': 70}}

# %%
# want to delete item
d.pop('age')
# Out:
# 26

# %%
d
# Out:
# {'name': 'ad', 'sub': {'ds': 78, 'da': 80, 'bd': 70}}

# %%
# want to delete name
d.pop('name')
# Out:
# 'ad'

# %%
d
# Out:
# {'sub': {'ds': 78, 'da': 80, 'bd': 70}}
