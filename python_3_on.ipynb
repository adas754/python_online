# %%
# create a string
s='hello'
type(s)
# Out:
# str

# %%
s="hello"
type(s)
# Out:
# str

# %%
s="""Z"""
type(s)
# Out:
# str

# %%
s='''''''python''''''' # big text
type(s)
# Out:
# str

# %%
s="python's formula"
type(s)
# Out:
# str

# %%
s=9.6 # convert numerical to categorical
s1=str(s)
s1
# Out:
# '9.6'

# %%
s='welcome to python'
s[1]
#s[:]='welcome'
#s[1]='l'
# Out:
# 'e'

# %%
s[-2]# indexing
s
s[0:3]
0-> w
1->e
2->l
3->c
4->o
5->m
6-e
7->''
# Out:
# 'welcome to python'

# %%
s[0:9]
s[11:]
#to
s[8:10]
#py
s[11:13]
s='welcome'
s[1:4:2]
s='python'
s[0:5:2]
# po
# Out:
# 'pto'

# %%
s='python'
s[0:5:4]
#ph
# p=0
#y=1
#t=2
#h=3
#o=4
s[0::3]
s='welcome'
s[0::3]
#wce
#s[0:7:3]
s='python string'
# ti
#s[8:11:2]
#s[2:11:8]
s[8:11:2]
s[::-1]
# mom
#madam
# nayan
# string is palindrom or not
s=input('Enter one string :')
# Out:
# Enter one string : python

# %%
s=input('Enter a string')
if s==s[::-1]:
    print('pal')
else:
    print('not pal')
#print(s)
# Out:
# Enter a string man
# not pal

# %%
#s==s[::-1]
s='python'
# nohthyp
s[::-1]

#s1=s[::-1]
#s==s1
# Out:
# 'nohtyp'

# %%
s='python'
s[0::3]
# Out:
# 'ph'

# %%
# w-> W
s[0]='W' #str immutable(indexwise editing is not possible inside str)

# %%
l=[8,9,10]
l[0]=7

# %%
l # mutable
# Out:
# [7, 9, 10]
