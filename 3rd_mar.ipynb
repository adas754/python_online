# %%
# email_id='ad12@gmail.com'
#password='ad123'
# u can login in insta
# u are failure
email_id='ad12@gmail.com'
password='ad123'
user_email=input('Enter a email_id')
user_password=input('enter password')
if email_id==user_email and password==user_password:
    print('login!')
else:
    print('fail to login')
# Out:
# Enter a email_id ad12@gmail.com
# enter password ad123
# login!

# %%
# email_id='ad12@gmail.com'
#password='ad123'
# if password is wrong then it will ask to give correct password
# if email_id is wrong it will ask to give correct email_id
# if both are correct u can login in insta
# if again not correct u are failure to login
email_id='ad12@gmail.com'
password='ad123'
user_email=input('Enter a email_id')
user_password=input('enter password')
if email_id==user_email and password==user_password:
    print('login!')
elif email_id==user_email and password!=user_password:
    print('give the correct password')
elif email_id!=user_email and password==user_password:
    print('give the correct mail id')
else:
    print('fail to login')
# Out:
# Enter a email_id thh
# enter password ghj
# fail to login

# %%
# email_id='ad12@gmail.com'
#password='ad123'
# if both are correct u can login in insta
# if password is wrong then it will ask to give correct password
# again if u give the wrong password
# print('wrong')
# if u give the correct password
# it will tell that success
# if email_id is wrong it will ask to give correct email_id
# if again not correct u are failure to login

# %%
email_id='ad12@gmail.com'
password='ad123'
user_email=input('Enter a email_id')
user_password=input('enter password')
if email_id==user_email and password==user_password:
    print('login!')
elif email_id==user_email and password!=user_password:
    print('password is wrong')
    user_password=input('plz enter the correct password')
    if user_password==password:
        print('success')
    else:
        print('failure')
    #print('give the correct password')
elif email_id!=user_email and password==user_password:
    print('give the correct mail id')
else:
    print('fail to login')
# Out:
# Enter a email_id ad12@gmail.com
# enter password yy
# password is wrong
# plz enter the correct password ad123
# success

# %%
# email_id='ad12@gmail.com'
#password='ad123'
# if both are correct u can login in insta
# if password is wrong then it will ask to give correct password
# again if u give the wrong password
# print('wrong')
# if u give the correct password
# it will tell that success
# if email_id is wrong it will ask to give correct email_id
# if again wrong then it will tell failure , wrong mail
# if correct then it will tell correct mail
# if again not correct u are failure to login

# %%
email_id='ad12@gmail.com'
password='ad123'
user_email=input('Enter a email_id')
user_password=input('enter password')
if email_id==user_email and password==user_password:
    print('login!')
elif email_id==user_email and password!=user_password:
    print('password is wrong')
    user_password=input('plz enter the correct password')
    if user_password==password:
        print('success')
    else:
        print('failure')
    #print('give the correct password')
elif email_id!=user_email and password==user_password:
    print('give the correct mail id')
    user_email=input('plz Enter a correct email_id again')
    if user_email==email_id:
        print('correct mail')
    else:
        print('wrong dont try with email')
else:
    print('fail to login')
# Out:
# Enter a email_id ffg
# enter password ad123
# give the correct mail id
# plz Enter a correct email_id again ad12@gmail.com
# correct mail

# %%
# loop
# why loop
# try to print 1 to 1000
# how you will print that
# print(1)
#print(2)
#................
# print(1000)

# %%
# for 
# while
# 1 to 10
# 1 to 5
i=1 #initialize the value
while i<=5:
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# print python 5 times
i=1 #initialize the value
while i<=5:
    print('python')
    i=i+1
# Out:
# python
# python
# python
# python
# python

# %%
# 1 3 5
i=1
while i<=5:
    print(i)
    i+=2
# Out:
# 1
# 3
# 5

# %%
i=1
while i<=5:
    if i%2!=0:
        print(i)
    i=i+1
# Out:
# 1
# 3
# 5

# %%
# 5 4 3 2 1
num = 5
while num >=1:
    print(num)
    num = num - 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
# print that multiplication table
# u have to take a number from user
# 5 
# 5*1=5
# 5*2=10
#----------
# 5*10 = 50

# 10*1 =10
# 10*2=20
#-------------
# 10*10=100

# %%
n=int(input('Enter a number'))
i=1
while i<11:
    print(n,'*',i,'=',n*i)
    i+=1
# Out:
# Enter a number 10
# 10 * 1 = 10
# 10 * 2 = 20
# 10 * 3 = 30
# 10 * 4 = 40
# 10 * 5 = 50
# 10 * 6 = 60
# 10 * 7 = 70
# 10 * 8 = 80
# 10 * 9 = 90
# 10 * 10 = 100

# %%
range(0,10)
# Out:
# range(0, 10)

# %%
list(range(0,11,4))
# Out:
# [0, 3, 6, 9]
