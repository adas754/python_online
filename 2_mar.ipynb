# %%
# operator
# arithmatic operator
# +,-,*,/,//,%,**

# %%
2+3
# Out:
# 5

# %%
2-3
# Out:
# -1

# %%
2*3
# Out:
# 6

# %%
5//2 # integer division
# Out:
# 2

# %%
9//2
# Out:
# 4

# %%
6/2
# Out:
# 3.0

# %%
5/2 # float division
# Out:
# 2.5

# %%
7/4
# Out:
# 1.75

# %%
7//4
# Out:
# 1

# %%
# modulus
7%2
# Out:
# 1

# %%
5%2
# Out:
# 1

# %%
6%3
# Out:
# 0

# %%
17%4
# Out:
# 1

# %%
7**2
# Out:
# 49

# %%
5**3
# Out:
# 125

# %%
4**4
# Out:
# 256

# %%
# relational operator
# >,<,>=,<=,==,!=

# %%
4>5
# Out:
# False

# %%
4<5
# Out:
# True

# %%
4<=4
# Out:
# True

# %%
5>=4
# Out:
# True

# %%
5!=4
# Out:
# True

# %%
5==5
# Out:
# True

# %%
5!=5
# Out:
# False

# %%
# logical operator
# and
# or 
# not
0 and 0
# Out:
# 0

# %%
0 and 1
# Out:
# 0

# %%
1 and 0
# Out:
# 0

# %%
1 and 1
# Out:
# 1

# %%
# or 
0 or 0
# Out:
# 0

# %%
0 or 1
# Out:
# 1

# %%
1 or 0
# Out:
# 1

# %%
1 or 1
# Out:
# 1

# %%
not 0
# Out:
# True

# %%
not 1
# Out:
# False

# %%
# Assignment operator
# =,+=,*=, /=,//=,%=,**=

# %%
a=5
a**=3
a
# Out:
# 125

# %%
a=a+2
a
# Out:
# 9

# %%
# membership operator
# not in
# in
'd' in 'delhi'
# Out:
# True

# %%
'D' in 'delhi'
# Out:
# False

# %%
'D' not in 'delhi'
# Out:
# True

# %%
10 in [1,5,7]
# Out:
# False

# %%
# conditional statement
# if 
# else 
# elif
# nested if else

# %%
5>10
# Out:
# False

# %%
a=5
if a>4: # condition satisfied
    print('ok')
# Out:
# ok

# %%
a=5
if a>10:
    print('ok')

# %%
a=4
if a>5: # condition not satisfied
    print('ok')

# %%
4>5
# Out:
# False

# %%
a=10
if a>20:
    print('no')
    
else:
    print('yes')
# Out:
# yes

# %%
# You have to check the no is even or odd
# user input

a=int(input('Enter a number'))
if a%2==0:
    print('even')
else:
    print('odd')
# Out:
# Enter a number 9
# odd

# %%
# check the string is palindrom or not
# u can use the indexing concept
# mom
# madam
# dad
# civic
# level
# radar
# noon
# racecar 
# malayalam
# refer

# %%
a=input('enter char')
a[::-1]
# Out:
# enter char python
# 'nohtyp'

# %%
a[::]
# Out:
# 'python'

# %%
a[::]==a[::-1]
# Out:
# False

# %%
a=input('enter char')
if a==a[::-1]:
    print('palindrome')
else:
    print('not palindrome')
# Out:
# enter char mom
# palindrome

# %%
# check the person is voter or not
age=int(input('Enter your age'))
if age>=18:
    print('go for vote')
else:
    print('no')
# Out:
# Enter your age 13
# no

# %%
# you have to check the no is positive or negative
a=int(input('Enter no'))
if a>0:
    print('+ve')
elif a==0:
    print('zero')
else:
    print('-ve')
# Out:
# Enter no -98
# -ve
