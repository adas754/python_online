# %%
#when we will start to create a function we have to write
# def
# add two number
def add(a,b):
    return a+b
add(8,0)
# Out:
# 8

# %%
# no arg no return
def no_arg():
    return()
no_arg()
# Out:
# ()

# %%
# no arg with return
def no_arg():
    return 'hi'
no_arg()
# Out:
# 'hi'

# %%
# with arg no return
def no_arg(a):
    return ()
no_arg(6)
# Out:
# ()

# %%
# with arg with return
def no_arg(a):
    return 'hi'
no_arg(6)
# Out:
# 'hi'

# %%
# add two number

# %%
# using no arg with return

# %%
def add():
    a=int(input())
    b=int(input())
    return a+b
add()
# Out:
#  8
#  9
# 17

# %%
# why not print
# why return
def func():
    print ('hi')
func()
# Out:
# hi

# %%
t=func()
type(t)
# Out:
# hi
# NoneType

# %%
def func():
    return ('hi')
func()
# Out:
# 'hi'

# %%
t=func()
type(t)
# Out:
# str

# %%
# check the string is palindrom or not

# %%
def check_palindrom(a):
    if a==a[::-1]:
        return 'pal'
    else:
        return 'not pal'
check_palindrom('momo')
# Out:
# 'not pal'

# %%
# u have to find no is even or odd

# %%
def even_odd(a):
    if a%2==0:
        return 'even'
    else:
        return 'odd'
even_odd(50)
# Out:
# 'even'

# %%
# try to find area of circle
def area_circle(r):
    return 3.14*r*r
area_circle(7)
# Out:
# 153.86

# %%
# try to find out square of number
def square(x):
    ''' this function is all about square of number
    return number what u want to square'''
    return x**2
square(6)
# Out:
# 36

# %%
print(square.__doc__)
# Out:
# this function is all about square of number
# return number what u want to square

# %%
# lambda
add= lambda x,y:x+y
add(9,9)
# Out:
# 18

# %%
# try to do multiplication using lambda
mul= lambda x,y:x*y
mul(9,9)
# Out:
# 81

# %%
# square of number
square=lambda x:x**2
square(6)
# Out:
# 36

# %%
# square of number
square=lambda x:x*x
square(6)
# Out:
# 36

# %%
# find out number is postitive or not
pos_neg=lambda a:'a is +ve' if a>0 else '-ve'

# %%
pos_neg(-9)
# Out:
# '-ve'

# %%
# try to find of maximum number among two

# %%
# 9,6

# %%
max_num= lambda a,b: a if a>b else b
max_num(9,90)
# Out:
# 90

# %%
# filter 
seq=[9,89,67,565,80]
# using filter it will featch only the even number

# %%
list(filter(lambda x:x%2==0,seq))
# Out:
# [80]

# %%
# try to filter out the odd number

# %%
list(filter(lambda x:x%2!=0,seq))
# Out:
# [9, 89, 67, 565]

# %%
seq=[90,78,56,89,67,890,5,8]
# u have to filter the number which one is greateer then 50
list(filter(lambda x:x>50,seq))
# Out:
# [90, 78, 56, 89, 67, 890]

# %%
# try to find out a string which one is starting with p
seq=['python','php','java','sql']

# %%
list(filter(lambda x:x.startswith('p'),seq))
# Out:
# ['python', 'php']

# %%
# map
seq=[9,90,89,67,60]
# even or odd
list(map(lambda x:'even' if x%2==0 else 'odd',seq))
# Out:
# ['odd', 'even', 'odd', 'odd', 'even']

# %%
l=[8,9,0]
l2=[7,8,9]
# 8+7,9+8,9

# %%
list(map(lambda x,y:x+y,l,l2))
# Out:
# [15, 17, 9]

# %%
l=[8,9,0]

# %%
# find it out the square of each and every number

# %%
list(map(lambda x:x**2,l))
# Out:
# [64, 81, 0]

# %%
# reduce

# %%
import functools

# %%
from functools import reduce
l=[8,9,0,6,9]
# i am trying to add each and every number
8+9+0+6+9
# Out:
# 32

# %%
functools.reduce(lambda x,y:x+y,l)
# Out:
# 32

# %%
# u have to find out the max number from list
l=[8,9,0,6,9]

# %%
functools.reduce(lambda x,y:x if x>y else y ,l)
# Out:
# 9

# %%
# try to find out minumum number

# %%
functools.reduce(lambda x,y:x if x<y else y ,l)
# Out:
# 0

# %%
import datetime
now=datetime.datetime.now()
now
# Out:
# datetime.datetime(2026, 3, 6, 8, 50, 3, 700872)

# %%
# exception handling

# %%
#

# %%
try:
    x=5/5
except: # try block will fail
    print('cant divisible by 0')
else: # try will work
    print('done')
finally:
    print('everything done') # try , else , each and every time 
    # will work
# Out:
# done
# everything done

# %%
try:
    x=1/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
}
