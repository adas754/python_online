# %%
# variable
a=15
# a= identifier
# a= 15 variable

# %%
# operator
#arithmatic operator
#+
9+5 # add
# Out:
# 14

# %%
9-5 #sub
# Out:
# 4

# %%
9*5 # multi
# Out:
# 45

# %%
9/2 # division always return float
# Out:
# 4.5

# %%
8/2
# Out:
# 4.0

# %%
9%2 # modulo (reminder)
# Out:
# 1

# %%
7%3
# Out:
# 1

# %%
9%3
# Out:
# 0

# %%
5%3
# Out:
# 2

# %%
5//2 # floor division (quotient)
# Out:
# 2

# %%
18//4
# Out:
# 4

# %%
6//4
# Out:
# 1

# %%
5**2 # exponential
# Out:
# 25

# %%
2**3
# Out:
# 8

# %%
#+,-,*,**,%,//,/

# %%
# relational operator

# %%
#<,<=,>,>=,==,!=

# %%
7<3
# Out:
# False

# %%
7<9
# Out:
# True

# %%
7<=8
# Out:
# True

# %%
9<=8
# Out:
# False

# %%
8<=8
# Out:
# True

# %%
9>=9
# Out:
# True

# %%
8==8
# Out:
# True

# %%
8==9
# Out:
# False

# %%
9==67
# Out:
# False

# %%
6!=6
# Out:
# False

# %%
5!=9
# Out:
# True

# %%
a=15
a
# Out:
# 15

# %%
9==9
# Out:
# True

# %%
3!=4
# Out:
# True

# %%
3!=3
# Out:
# False

# %%
9==8
# Out:
# False

# %%
# logical operator
# and , or , not
0 or 1
# Out:
# 1

# %%
True or True
# Out:
# True

# %%
1 or 1
# Out:
# 1

# %%
0 or 0
# Out:
# 0

# %%
0 or 1
# Out:
# 1

# %%
1 or 0
# Out:
# 1

# %%
1 or 1
# Out:
# 1

# %%
# and gate

# %%
0 and 0
# Out:
# 0

# %%
1 and 1
# Out:
# 1

# %%
not 0
# Out:
# True

# %%
not 1
# Out:
# False

# %%
#assignment operator(=,+=,*=,**=,/=,//=,%=)
a=14
a
# Out:
# 14

# %%
a=14
#a=a+2
a+=2
a
# Out:
# 16

# %%
a=9
a**=3
a
# Out:
# 729

# %%
9**3
# Out:
# 729

# %%
a=9
a*=3
a
# Out:
# 27

# %%
a=9
a**=3
a
# Out:
# 729

# %%
9**3
# Out:
# 729

# %%
a=9
a%=2
a
# Out:
# 1

# %%
9%2
# Out:
# 1

# %%
# % -> reminder

# %%
# membership operator
# in 
# not in

'P' in 'python'
# Out:
# False

# %%
'p' not in 'java'
# Out:
# True

# %%
't' not in 'True'
# Out:
# True

# %%
9
# Out:
# 9

# %%
print(True)
# Out:
# True

# %%
print(9,9.0,'python',False,sep='!')
# Out:
# 9!9.0!python!False

# %%
print(9,9.0,'python',False)
# Out:
# 9 9.0 python False

# %%
print(9,9.0,'py',False,sep='&')
# Out:
# 9&9.0&py&False

# %%
print('learn',end= ' java and ')
print('python')
# learn python
# learn
# python
# Out:
# learn java and python

# %% [markdown]
# # string
# # indexing
# s='python'
# p 0 -6
# y 1 -5
# t 2 -4
# h 3 -3
# 0 4 -2
# n 5 -1

# %%
s='python'
s[4]
# Out:
# 'o'

# %%
s[2]
# Out:
# 't'

# %%
s='python'
p 0 -6
y 1 -5
t 2 -4
h 3 -3
0 4 -2
n 5 -1

# %%
s[-3]
# Out:
# 'h'
