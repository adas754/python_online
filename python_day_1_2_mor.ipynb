# %% [markdown]
# ### python basics

# %%
# esc+a -> to add the new cell above
# esc+b-> to add the new cell below
# esc+dd -> to delete the cell

# %%
# python datatype
# numerical
# int
# float
# str
# bool(True,False)
#complex (a+ij)
# 9
#type(9)
type('''''''python''''''')
#type(28.9)
# Out:
# str

# %%
type("python")
# Out:
# str

# %%
type('2.0')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type('false')
# Out:
# str

# %%
type(8+9j)
# Out:
# complex

# %%
type(8.9+9.7j) #a+ij
# Out:
# complex

# %%
type("9.0")
# Out:
# str

# %%
type(89.00)
# Out:
# float

# %%
type(9.6)
# Out:
# float

# %%
type(1)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(9+8j)
# Out:
# complex

# %%
# identifier
# how to define the identifier
a=9 # we can define str as identifier
#1=9 # we cant define number as identifier
a1=9 #alpha numerical is fine but  we should
# starts with alphabet
#1a=9
_=9 # each and every spl char it will 
# throw error except _

# %%
#! = 9

# %%
num=8

# %%
#for=9

# %%
# keyword we will use for specific task
# we cant use keyword as identifier
import keyword
len(keyword.kwlist)
# Out:
# 35

# %%
a19=8

# %%
# starting with str yes
# starting with float no
# starting with int no
# starting with ^ no
# ^=0
# _=0
# except _ it will throw error

# %%
# 10:17

# %%
9
# Out:
# 9

# %%
print(9)
# Out:
# 9

# %%
print(9.0)
# Out:
# 9.0

# %%
print(1,9.0,'python',True,sep='%')
# Out:
# 1%9.0%python%True

# %%
print('hi')
print('python')
# Out:
# hi
# python

# %%
print('hi', end ='&')
print('python')
# Out:
# hi&python

# %%
print('hi',end='&')
print('hlw')
# Out:
# hi&hlw

# %%
# operator
# arithmatic operator
# +,-,*,**,%,//,/
print(9*7)
print(9+9)
print(8-6)
print(8/3)
print(8//3)
print(9//8)
print(7//2)
print(7%3)
print(6%2)
# Out:
# 63
# 18
# 2
# 2.6666666666666665
# 2
# 1
# 3
# 1
# 0

# %%
85//17
# Out:
# 5

# %%
7**3
# Out:
# 343

# %%
# relational operator
# ==,!=,>,<,>=,<=
# logical operator
# and
# or
# not

# %%
print(9!=8)
# Out:
# True

# %%
print(8>7)
# Out:
# True

# %%
print(8<3)
# Out:
# False

# %%
print(9>=90)
# Out:
# False

# %%
0 and 1
# Out:
# 0

# %%
1 or 0
# Out:
# 1

# %%
not 1
# Out:
# False

# %%
# assignment 
# +=,-=,*=,**=,=

# %%
a=9
a+=2
a
# Out:
# 11

# %%
a=9
a=a+2 # a+=2
a
# Out:
# 11

# %%
a=98
a-=98
a
# Out:
# 0

# %%
a=0
a*=900000
a
# Out:
# 0

# %%
a=9
a%=8
a
# Out:
# 1

# %%
a=9
a**=2
a
# Out:
# 81

# %%
a=9
a=a**2 #a**=2
a
# Out:
# 81

# %%
# membership op
# in 
# not in

# %%
'pn' not in 'python'
# Out:
# True

# %%
# how to add two number
a=9
b=0
a+b
# Out:
# 9

# %%
a=float(input('plz enter 1st no'))
b=float(input('plz enter 2nd no'))
a*b
# Out:
# plz enter 1st no 8.3
# plz enter 2nd no 0
# 0.0

# %%
a=eval(input('plz enter 1st no'))
b=eval(input('plz enter 2nd no'))
a*b
# Out:
# plz enter 1st no 8
# plz enter 2nd no 6.0
# 48.0

# %%
# swap two nummber
# a=9
# b=6
#-------
#a=6
#b=9
a=int(input('enter 1st no'))
b=int(input('enter 2nd no'))
a=a+b #a=9+6=15
b=a-b #b=15-6=9
a=a-b #15-9=6
print('after swapping')
print(a)
print(b)
# Out:
# enter 1st no 9
# enter 2nd no 6
# after swapping
# 6
# 9

# %%
# a=9
# b=6
# a=a+b=9+6=15
# b=a-b= 15-6=9
# a=a-b 15-9=6

# %%
# string
a='python'
# indexing
# +ve indexing
# -ve indexing
a[2]
# Out:
# 't'

# %%
a[-3]
# Out:
# 'h'

# %%
a='welcome'
# w
# e
# m
a[-2]
# Out:
# 'm'

# %%
a='welcome to python'

# %%
a[10]
# Out:
# ' '

# %%
#slicing
a
# Out:
# 'welcome to python'

# %%
a[11:13]
# Out:
# 'py'

# %%
a
# Out:
# 'welcome to python'

# %%
# on
a[15:6000000000000000000]
# Out:
# 'on'

# %%
a[11:999999999999999999999999999999999999999999]
# Out:
# 'python'

# %%
a[11:]
# Out:
# 'python'

# %%
a
# Out:
# 'welcome to python'

# %%
#come
a[3:7]
# Out:
# 'come'

# %%
# to
a[8:13]
# Out:
# 'to py'

# %%
a
# Out:
# 'welcome to python'

# %%
# wce
a[0:7:3]
# Out:
# 'wce'

# %%
a
# Out:
# 'welcome to python'

# %%
# nohtyp
a[-1:-7:-1]
# Out:
# 'nohtyp'

# %%
a
# Out:
# 'welcome to python'

# %%
# py
a[-6:-4]
# Out:
# 'py'

# %%
a[-7:-4]
# Out:
# ' py'

# %%
a
# Out:
# 'welcome to python'

# %%
# no
a[-1:-3:-1]
# Out:
# 'no'

# %%
a[::]
# Out:
# 'welcome to python'

# %%
a[::-1]
# Out:
# 'nohtyp ot emoclew'

# %%
a
# Out:
# 'welcome to python'

# %%
# emoc
a[-11:-15:-1]
# Out:
# 'emoc'

# %%
a
# Out:
# 'welcome to python'

# %%
a[-14:-10]
# Out:
# 'come'

# %%
a
# Out:
# 'welcome to python'

# %%
#yt
a[-5:-3]
# Out:
# 'yt'

# %%
a[-4:-6:-1]
# Out:
# 'ty'

# %%
a
# Out:
# 'welcome to python'

# %%
a[13:11:-1]
# Out:
# 'ty'

# %%
a
# Out:
# 'welcome to python'

# %%
a
# Out:
# 'welcome to python'

# %%
a=7
a1=str(a)
a1
# Out:
# '7'

# %%
a='py'
#=int(a)
#a1

# %%
# inbuilt function in string
a
# Out:
# 'py'

# %%
a='welcome to python'
len(a)
# Out:
# 17

# %%
max(a)
# Out:
# 'y'

# %%
min(a)
# Out:
# ' '

# %%
sorted(a)
# Out:
# [' ',
#  ' ',
#  'c',
#  'e',
#  'e',
#  'h',
#  'l',
#  'm',
#  'n',
#  'o',
#  'o',
#  'o',
#  'p',
#  't',
#  't',
#  'w',
#  'y']

# %%
sorted(a,reverse=True)
# Out:
# ['y',
#  'w',
#  't',
#  't',
#  'p',
#  'o',
#  'o',
#  'o',
#  'n',
#  'm',
#  'l',
#  'h',
#  'e',
#  'e',
#  'c',
#  ' ',
#  ' ']

# %%
'python'>'Python'
# Out:
# True

# %%
'python'<'Python'
# Out:
# False

# %%
'Japan'>'Japan'
# Out:
# False

# %%
' ' and 'java'
# Out:
# 'java'

# %%
'java' and ' '
# Out:
# ' '

# %%
'java' or ' '
# Out:
# 'java'

# %%
'java' and ''
# Out:
# ''

# %%
''and 'py'
# Out:
# ''

# %%
a
# Out:
# 'welcome to python'

# %%
# how many times n is there
a.count('o')
# Out:
# 3

# %%
'hi'+' python'
# Out:
# 'hi python'

# %%
'hi'*3
# Out:
# 'hihihi'

# %%
a
# Out:
# 'welcome to python'

# %%
#a.reverse()

# %%
# upper
# lower
# capitalize
# title

# %%
a
# Out:
# 'welcome to python'

# %%
a.upper()
# Out:
# 'WELCOME TO PYTHON'

# %%
a.lower()
# Out:
# 'welcome to python'

# %%
a.title()
# Out:
# 'Welcome To Python'

# %%
a
# Out:
# 'welcome to python'

# %%
a.capitalize()
# Out:
# 'Welcome to python'

# %%
a='PytHon'
a.swapcase()
# Out:
# 'pYThON'

# %%
# upper -> upper
# lower-> lower
# title-> first letter of each and every word
# capitalize-> only 1st letter in sent
# swapcase-> upper-> lower ,lower-> upper

# %%
a
# Out:
# 'PytHon'

# %%
a='Welcome To Python'
a.index('n')
# Out:
# 16

# %%
#a.index('z')

# %%
a='Welcome To Python'
a.find('z')
# Out:
# -1

# %%
a
# Out:
# 'Welcome To Python'

# %%
a.find('p')
# Out:
# -1

# %%
# both index and find 
# index number
# find - > if any value is not there it will give -1
# index -> error

# %%
a='python#'
a.isalpha()
# Out:
# False

# %%
a='23#'
a.isdigit()
# Out:
# False

# %%
a='56#'
a.isalnum()
#isalnum-> alpha+numeric
# only alphabet
# only numerical
# spc char will not allow
# Out:
# False
